# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Web Scraping Exercises
#
# ## Complete the Tasks Below

# %% [markdown]
# **TASK: Import any libraries you think you'll need to scrape a website.**

# %%
# CODE HERE

# %%
import requests
import bs4

# %% [markdown]
# **TASK: Use requests library and BeautifulSoup to connect to http://quotes.toscrape.com/ and get the HMTL text from the homepage.**

# %%
# CODE HERE

# %%
req = requests.get('http://quotes.toscrape.com/')

# %%
soup = bs4.BeautifulSoup(req.text, "lxml")

# %% [markdown]
# **TASK: Get the names of all the authors on the first page.**

# %%
authors = []
for author in soup.select('.author'):
    authors.append(author.text)
print(set(authors))
# Out:
# {'André Gide', 'Jane Austen', 'Thomas A. Edison', 'Albert Einstein', 'J.K. Rowling', 'Marilyn Monroe', 'Eleanor Roosevelt', 'Steve Martin'}

# %%
authors
# Out:
# {'Albert Einstein',
#  'André Gide',
#  'Eleanor Roosevelt',
#  'J.K. Rowling',
#  'Jane Austen',
#  'Marilyn Monroe',
#  'Steve Martin',
#  'Thomas A. Edison'}

# %% [markdown]
# **TASK: Create a list of all the quotes on the first page.**

# %%
for quote in soup.select('.text'):
    print(quote.text)
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# “Try not to become a man of success. Rather become a man of value.”
# “It is better to be hated for what you are than to be loved for what you are not.”
# “I have not failed. I've just found 10,000 ways that won't work.”
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# “A day without sunshine is like, you know, night.”

# %%
quotes
# Out:
# ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”',
#  '“It is our choices, Harry, that show what we truly are, far more than our abilities.”',
#  '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”',
#  '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”',
#  "“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”",
#  '“Try not to become a man of success. Rather become a man of value.”',
#  '“It is better to be hated for what you are than to be loved for what you are not.”',
#  "“I have not failed. I've just found 10,000 ways that won't work.”",
#  "“A woman is like a tea bag; you never know how strong it is until it's in hot water.”",
#  '“A day without sunshine is like, you know, night.”']

# %% [markdown]
# **TASK: Inspect the site and use Beautiful Soup to extract the top ten tags from the requests text shown on the top right from the home page (e.g Love,Inspirational,Life, etc...). HINT: Keep in mind there are also tags underneath each quote, try to find a class only present in the top right tags, perhaps check the span.**

# %%
import re
tags = soup.select('.tag-item')


for tag in tags:
    print(tag.text)
# Out:
# love
#
#
# inspirational
#
#
# life
#
#
# humor
#
#
# books
#
#
# reading
#
#
# friendship
#
#
# friends
#
#
# truth
#
#
# simile

# %%
import re
tags = soup.select('.tag-item')


for tag in tags:
    mystr = str(tag)
    topic = re.search(r'>\w+<',mystr)
    print(topic.group())
    print('\n')
# Out:
# >love<
#
#
# >inspirational<
#
#
# >life<
#
#
# >humor<
#
#
# >books<
#
#
# >reading<
#
#
# >friendship<
#
#
# >friends<
#
#
# >truth<
#
#
# >simile<

# %%
# Out:
# love
#
#
# inspirational
#
#
# life
#
#
# humor
#
#
# books
#
#
# reading
#
#
# friendship
#
#
# friends
#
#
# truth
#
#
# simile

# %% [markdown]
# **TASK: Notice how there is more than one page, and subsequent pages look like this http://quotes.toscrape.com/page/2/. Use what you know about for loops and string concatenation to loop through all the pages and get all the unique authors on the website. Keep in mind there are many ways to achieve this, also note that you will need to somehow figure out how to check that your loop is on the last page with quotes. For debugging purposes, I will let you know that there are only 10 pages, so the last page is http://quotes.toscrape.com/page/10/, but try to create a loop that is robust enough that it wouldn't matter to know the amount of pages beforehand, perhaps use try/except for this, its up to you!**

# %%
req = requests.get(f'http://quotes.toscrape.com/page/12/')
soup = bs4.BeautifulSoup(req.text, "lxml")
# Out:
# True

# %%
n = 2
while True:
       
    
    req = requests.get(f'http://quotes.toscrape.com/page/{n}/')


    soup = bs4.BeautifulSoup(req.text, "lxml")

    
    
    
    
    if 'No quotes found' in req.text:
        break
    
    
    
    
    else:

 
        for author in soup.select('.author'):
            authors.append(author.text)
        

        n += 1
print(set(authors))
# Out:
# {'James Baldwin', 'Jimi Hendrix', 'Garrison Keillor', 'Eleanor Roosevelt', 'E.E. Cummings', 'Mother Teresa', 'Charles Bukowski', 'Terry Pratchett', 'George Carlin', 'Alfred Tennyson', 'Allen Saunders', 'J.D. Salinger', 'Albert Einstein', 'C.S. Lewis', 'Harper Lee', 'Ernest Hemingway', 'Marilyn Monroe', 'Dr. Seuss', 'Stephenie Meyer', 'George Bernard Shaw', 'Pablo Neruda', 'Jorge Luis Borges', 'André Gide', 'Suzanne Collins', 'William Nicholson', 'Bob Marley', 'Ralph Waldo Emerson', 'Thomas A. Edison', 'Martin Luther King Jr.', 'Charles M. Schulz', 'George Eliot', 'Helen Keller', 'John Lennon', 'Douglas Adams', 'J.R.R. Tolkien', "Madeleine L'Engle", 'Elie Wiesel', 'Jane Austen', 'George R.R. Martin', 'Ayn Rand', 'Haruki Murakami', 'Alexandre Dumas fils', 'Khaled Hosseini', 'J.K. Rowling', 'W.C. Fields', 'Friedrich Nietzsche', 'J.M. Barrie', 'Steve Martin', 'Mark Twain', 'Jim Henson'}

# %% [markdown]
# There are lots of other potential solutions that are even more robust and flexible, the main idea is the same though, use a while loop to cycle through potential pages and have a break condition based on the invalid page.
